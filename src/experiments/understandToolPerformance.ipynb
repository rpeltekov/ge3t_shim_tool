# %% [markdown]
# ### Trying to understand what happens when you shift center frequency more.

# %%
import argparse
import signal
import subprocess
import sys
import numpy as np
import matplotlib.pyplot as plt
import tqdm
import time
from helpersFunctions import *
import ipywidgets as widgets
from IPython.display import display, clear_output

sys.path.append('..')

# %%
# print out the current path

from shimTool.Tool import Tool, ShimMode
from shimTool.dicomUtils import *
from shimTool.shimCompute import *


def load_tool():
    if "tool" in globals():
        del globals()["tool"]
    config = load_config("/home/heartvista/Documents/robert/ge3t_shim_tool/config.json")
    return Tool(config, debugging=True)

# %%
# want to now set an ROI, or lets say look at values only in the 2nd fifth of the image, or also for the whole volume as well
def printStats(fieldmap):
    std = np.nanstd(fieldmap)
    mean = np.nanmean(fieldmap)
    print("Mean: ", mean)
    print("Std Dev: ", std)

def compare(fieldmap1, fieldmap2):
    diff = fieldmap2 - fieldmap1
    # get std dev and mean
    print("Difference Statistics:")
    printStats(diff)
    return diff

# %% [markdown]
# # Testing that center frequency knob moves off resonance as expected in the image

# %%
# create a new shim tool object
tool = load_tool()

# %%
# want to get a background
tool.doCalibrationScan()
#tool.exsiInstance.bedPosition = 0
tool.doFieldmapScan()
background = computeFieldmapFromLatestFieldmapScan(tool)

# %%
print("Background Fieldmap Stats: ", printStats(background))

# %% [markdown]
# ### Test some one off CF changes

# %%
# want to change the center frequency
tool.setCenterFrequency(99)

# %%
# want to acquire another field map
tool.doFieldmapScan()
actual = computeFieldmapFromLatestFieldmapScan(tool)
print("Actual Fieldmap Stats: ", printStats(actual))

# %%
# whole volume:
print("Difference between my 2 scan fieldmap background and after change in center frequency:")
diff = compare(background, actual)

# %%
# want to change the center frequency
tool.setCenterFrequency(-20)

# %%
# want to acquire another field map
tool.doFieldmapScan()
actual = computeFieldmapFromLatestFieldmapScan(tool)
print("Actual Fieldmap Stats: ", printStats(actual))

# %%
# whole volume:
print("Difference between my 2 scan fieldmap background and after change in center frequency:")
diff = compare(background, actual)

# %% [markdown]
# ## Acquire data to show that aggregate center frequency adjustment is reflected in my fieldmaps

# %%
cf_changes = list(range(-300, 301,20))
actual_changes = []
for change in cf_changes:
    print("----------------------------------------------------")
    print(f"Changing center frequency by {change}")
    tool.setCenterFrequency(change)
    tool.doFieldmapScan()
    actual = computeFieldmapFromLatestFieldmapScan(tool)
    print(f"Actual Fieldmap Stats after changing center frequency by {change}: ")
    printStats(actual)
    diff = compare(background, actual)
    actual_changes.append(np.nanmean(diff))

# %% [markdown]
# ### Note: with a 3.5ms TE, we will see wrapping at ~|140| hz offset from cf

# %%
print("Actual Changes: ", actual_changes)
print("expected Frequency Changes: ", cf_changes)
actual_changes = np.array(actual_changes)
cf_changes = np.array(cf_changes)

difference =  cf_changes - actual_changes
print(f"From the difference of expected - achieved changes in center frequency,\n\t absolute error has a mean of {np.mean(difference)} and std dev of: ", np.std(difference))
# plot scatter of the actual changes and the expected changes
plt.figure(figsize=(15,10))
plt.plot(cf_changes, difference)
# make the plot extra wide and show every single x point
plt.xticks(cf_changes, rotation=90)
plt.yticks(range(-300,301,20))
plt.grid()
plt.title("Error of measured mean offresonance after CF changes")
plt.xlabel("Applied Center Frequency Adjustment (Hz)")
plt.ylabel("Error between desired and observed mean offresonance (Hz)")

# %%
mask = np.abs(cf_changes) < 140

subset_cf_changes = cf_changes[mask]
subset_difference = difference[mask]

plt.figure(figsize=(15,10))
plt.plot(subset_cf_changes, subset_difference)
# make the plot extra wide and show every single x point
plt.xticks(subset_cf_changes, rotation=90)
plt.yticks(range(-20,21,2))
plt.grid()
plt.title("Error of measured mean offresonance after CF changes")
plt.xlabel("Applied Center Frequency Adjustment (Hz)")
plt.ylabel("Error between desired and observed mean offresonance (Hz)")

print(f"From the difference of expected - achieved changes in center frequency,\n\t absolute error has a mean of {np.mean(subset_difference)} and std dev of: ", np.std(subset_difference))

# %%
mask = cf_changes < -140

subset_cf_changes = cf_changes[mask]
subset_difference = difference[mask]

plt.plot(subset_cf_changes, subset_difference)
# make the plot extra wide and show every single x point
plt.xticks(subset_cf_changes, rotation=90)
plt.yticks(range(-290,-260,3))
plt.grid()
plt.title("Error of measured mean offresonance after CF changes")
plt.xlabel("Applied Center Frequency Adjustment (Hz)")
plt.ylabel("Error between desired and observed mean offresonance (Hz)")

print(f"From the difference of expected - achieved changes in center frequency,\n\t absolute error has a mean of {np.mean(subset_difference)} and std dev of: ", np.std(subset_difference))

# %%
mask = cf_changes > 160

subset_cf_changes = cf_changes[mask]
subset_difference = difference[mask]

plt.plot(subset_cf_changes, subset_difference)
# make the plot extra wide and show every single x point
plt.xticks(subset_cf_changes, rotation=90)
plt.yticks(range(270,300,3))
plt.grid()
plt.title("Error of measured mean offresonance after CF changes")
plt.xlabel("Applied Center Frequency Adjustment (Hz)")
plt.ylabel("Error between desired and observed mean offresonance (Hz)")

print(f"From the difference of expected - achieved changes in center frequency,\n\t absolute error has a mean of {np.mean(subset_difference)} and std dev of: ", np.std(subset_difference))

# %% [markdown]
# ## get some more fine grain data within the non-wrapping range of cf adjustments

# %%
tool.autoPrescanDone = False
tool.doFieldmapScan()
background = computeFieldmapFromLatestFieldmapScan(tool)

# %%
print("Background Fieldmap Stats: ", printStats(background))
background_center = np.nanmean(background).astype(np.int32)
print(background_center)

# %%
cf_changes = list(range(-150-background_center, 151-background_center,10))
actual_changes = []
for change in cf_changes:
    print("----------------------------------------------------")
    print(f"Changing center frequency by {change}")
    tool.setCenterFrequency(change)
    tool.doFieldmapScan()
    actual = computeFieldmapFromLatestFieldmapScan(tool)
    print(f"Actual Fieldmap Stats after changing center frequency by {change}: ")
    printStats(actual)
    diff = compare(background, actual)
    actual_changes.append(np.nanmean(diff))
actual_changes = np.array(actual_changes)
cf_changes = np.array(cf_changes)
print("Actual Changes: ", actual_changes)
print("expected Frequency Changes: ", cf_changes)
difference =  cf_changes - actual_changes
pint("differences: ", difference)
print(f"From the difference of expected - achieved changes in center frequency,\n\t absolute error has a mean of {np.mean(difference)} and std dev of: ", np.std(difference))
# plot scatter of the actual changes and the expected changes
plt.plot(cf_changes, difference)
plt.title("Error of measured mean offresonance after CF changes")
plt.xlabel("Applied Center Frequency Adjustment (Hz)")
plt.ylabel("Error between desired and observed mean offresonance (Hz)")

# %% [markdown]
# ### get two scans done with ideal and see if their differences are similar to the differences from my scan...

# %%
# acquire idea fieldmap manually. verify the ideal scans you want are here
tool.transferScanData()

for subdir in listSubDirs(tool.localExamRootDir):
    p = os.path.join(tool.localExamRootDir, subdir)
    d = listDicomFiles(p)[0]
    print(d)
    ds = pydicom.dcmread(d)
    print(getattr(ds, 'SeriesDescription'))

# %%
# for each image in the directory, mask it and construct the fieldmap obtained by IDEAL sequence of the background
def getDicomArrayFromDir(dicomDir) -> np.ndarray:
    dicomArray = []
    for img in listDicomFiles(dicomDir):
        ds = pydicom.dcmread(img)
        dicomArray.append(ds.pixel_array)
    return np.stack(dicomArray, axis=0)

def getIdealFieldmapFromDir(waterDicomDir, fieldmapDicomDir, threshold=0.5):
    water = getDicomArrayFromDir(waterDicomDir).astype(np.float32)
    fieldmap = getDicomArrayFromDir(fieldmapDicomDir).astype(np.float32)
    mask = water < np.nanmean(water) * threshold
    fieldmap[mask] = np.nan
    return fieldmap

# %%
waterDicomDirIDEALBackground, FieldmapDicomDirIDEALBackground = listSubDirs(tool.localExamRootDir)[-4:-2]
print(waterDicomDirIDEALBackground, FieldmapDicomDirIDEALBackground)
background_IDEAL = getIdealFieldmapFromDir(waterDicomDirIDEALBackground, FieldmapDicomDirIDEALBackground, threshold=.4)
print("'After' Fieldmap IDEAL Stats: ", printStats(background_IDEAL))

# %%
waterDicomDirIDEALAfter, FieldmapDicomDirIDEALAfter = listSubDirs(tool.localExamRootDir)[-2:]
print(waterDicomDirIDEALAfter, FieldmapDicomDirIDEALAfter)
after_IDEAL = getIdealFieldmapFromDir(waterDicomDirIDEALAfter, FieldmapDicomDirIDEALAfter, threshold=.4)
print("Background Fieldmap IDEAL Stats: ", printStats(after_IDEAL))

# %%
# whole volume:
print("Difference between my 2 scan fieldmap background and after change in center frequency:")
diff = compare(background_IDEAL, after_IDEAL)

# %% [markdown]
# # Testing before and after CF is applied for a specific solution once gradients are applied

# %% [markdown]
# ## Setup

# %%
# from the computed solutions:
    #   for a slice on isocenter (slice 31), 
    #   slice off isocenter (slice 20), 
    #   the whole volume, 
    #   and the volume of the ROI, 
    # apply the shim values and compare the results
def applyShimAndCompare(tool: Tool, sliceIdx: int = None):
    tool.setCenterFrequency(deltaCF=0)
    print("Setting gradients only now")
    tool.setLinGradients(deltaLinGrad=tool.getSolutionsToApply(sliceIdx)[1:4])
    tool.doFieldmapScan()
    before = computeFieldmapFromLatestFieldmapScan(tool)
    print("Stats of the actual acquired fieldmap after only changing the linear gradients:\n", tool.shimStatStrsVolume[2])
    print("\nSetting Center frequency now")
    tool.setCenterFrequency(deltaCF=tool.getSolutionsToApply(sliceIdx)[0])
    tool.doFieldmapScan()
    print("Stats of the actual acquired fieldmap after only changing the linear gradients:\n", tool.shimStatStrsVolume[2])
    after = computeFieldmapFromLatestFieldmapScan(tool)
    return before, after

# %%
# reset the shim tool object 
tool = load_tool()

# %%
# acquire a new background
tool.doCalibrationScan()
tool.doFieldmapScan()
background = computeFieldmapFromLatestFieldmapScan(tool)

# for viewing purposes
tool.getROIBackgound()
background_mag = tool.viewData[0]

# %%
# acquire basis maps of the gradients
tool.doBasisCalibrationScans()

# %% [markdown]
# ## Volume wise

# %%
tool.setShimMode(ShimMode.VOLUME)
tool.recomputeCurrentsAndView()

# %%
print("principle sols", tool.principleSols)
print("solutions to apply for the volume", tool.getSolutionsToApply())
print("\nstats of the background:\n", tool.shimStatStrsVolume[0])
print("\nstats for expected:\n", tool.shimStatStrsVolume[1])

# %%
# Entire Volume
beforeCFMoved, afterCFMoved = applyShimAndCompare(tool, None)
print('\n\n')
diff = compare(background, beforeCFMoved)
print("Comparing background with after CF moved")
diff = compare(background, afterCFMoved)
print("Comparing before CF moved with after CF moved")
diff = compare(beforeCFMoved, afterCFMoved)

# %% [markdown]
# ## Slice Wise

# %%
tool.setShimMode(ShimMode.SLICE)
tool.recomputeCurrentsAndView()

# %%
# for a slice on isocenter
# add a slider to select the slice
sliceSlider = widgets.IntSlider(description='Slice Idx:', disabled=False)
output_widget = widgets.Output()
startEvalScan = widgets.Button(description='Start Eval Scan')
sliceSlider.max = len(tool.shimStatsPerSlice[0]) - 1  # Update slider range
sliceSlider.value = 0  # Reset to first image
sliceIdx =  0 


# Update the displayed image when the slider value changes
def on_slider_value_change(change):
    if change['new'] is not None:
        sliceIdx = change['new']

        # visualize that slice
        with output_widget:
            clear_output(wait=True)
            plt.imshow(background_mag[:,sliceIdx], cmap='gray')
            plt.show()

            print("principle sols", tool.principleSols)
            print("solutions to apply for the volume", tool.getSolutionsToApply(sliceIdx))
            print("\nstats of the background:\n", tool.shimStatStrsPerSlice[0][sliceIdx])
            print("\nstats for expected:\n", tool.shimStatStrsPerSlice[1][sliceIdx])

def init_slice_eval(b):
    with output_widget:
        print("\n-------------")
        print(f"Evaluating results on Slice {sliceSlider.value}\n")
        beforeCFMoved, afterCFMoved = applyShimAndCompare(tool, sliceSlider.value)

        print("\n\nComparing background with before CF moved")
        diff = compare(background, beforeCFMoved)
        print("Comparing background with after CF moved")
        diff = compare(background, afterCFMoved)
        print("Comparing before CF moved with after CF moved")
        diff = compare(beforeCFMoved, afterCFMoved)
sliceSlider.observe(on_slider_value_change, names='value')

startEvalScan.on_click(init_slice_eval)
# Layout the widgets
widgets_layout = widgets.VBox([sliceSlider, startEvalScan, output_widget])
display(widgets_layout)

# %% [markdown]
# ## Volume with specific ROI

# %%
# volume of the ROI
tool.setShimMode(ShimMode.VOLUME)

# somehow set an ROI that makes sense to you... it would be nice to be able to spawn the gui and select the ROI manually...that would be cool... 
# for now, lets just set a circle in the center of the image
ydim, zdim, xdim = tool.viewData[0].shape
tool.ROI.setROILimits(xdim, ydim, zdim)
tool.ROI.sizes[0] = max(1, round((tool.ROI.xdim // 2) * .35))
tool.ROI.sizes[1] = max(1, round((tool.ROI.ydim // 2) * .25))
tool.ROI.sizes[2] = max(1, round((tool.ROI.zdim // 2) * .15))
tool.ROI.centers[0] = round(tool.ROI.xdim * .5)
tool.ROI.centers[1] = round(tool.ROI.ydim * .45)
tool.ROI.centers[2] = round(tool.ROI.zdim * .75)
tool.ROI.enabled = True
tool.ROI.updated = True
tool.computeMask()
tool.recomputeCurrentsAndView()
tool.cropViewDataToFinalMask()

# %%
background_cropped = np.copy(background_mag).astype(np.float32)
background_cropped[~tool.finalMask] = np.nan

# %%
# for a slice on isocenter
# add a slider to select the slice
sliceSlider = widgets.IntSlider(description='Slice Idx:', disabled=False)
output_widget = widgets.Output()
sliceSlider.max = len(tool.shimStatsPerSlice[0]) - 1  # Update slider range
sliceSlider.value = 0  # Reset to first image
sliceIdx =  0 


# Update the displayed image when the slider value changes
def on_slider_value_change(change):
    if change['new'] is not None:
        sliceIdx = change['new']

        # visualize that slice
        with output_widget:
            clear_output(wait=True)
            plt.imshow(background_cropped[:,sliceIdx], cmap='gray')
            plt.show()

            print("principle sols", tool.principleSols)
            print("solutions to apply for the volume", tool.getSolutionsToApply(sliceIdx))
            print("\nstats of the background:\n", tool.getSolutionStrings(0))
            print("\nstats for expected:\n", tool.getSolutionStrings(1))

sliceSlider.observe(on_slider_value_change, names='value')

# Layout the widgets
widgets_layout = widgets.VBox([sliceSlider, output_widget])
display(widgets_layout)

# %%
# for a slice on isocenter
# add a slider to select the slice
startEvalScan = widgets.Button(description='Start Eval Scan')
output_widget = widgets.Output()

def init_slice_eval(b):
    with output_widget:
        print("\n-------------")
        print(f"Evaluating results on ROI")
        beforeCFMoved, afterCFMoved = applyShimAndCompare(tool, None)

        print("\n\nComparing background with before CF moved")
        diff = compare(background, beforeCFMoved)
        print("Comparing background with after CF moved")
        diff = compare(background, afterCFMoved)
        print("Comparing before CF moved with after CF moved")
        diff = compare(beforeCFMoved, afterCFMoved)

startEvalScan.on_click(init_slice_eval)
# Layout the widgets
widgets_layout = widgets.VBox([startEvalScan, output_widget])
display(widgets_layout)

# %% [markdown]
# ## Looking to evaluate the gradients and how they get applied one by one...

# %%
def applyGradients1by1(tool: Tool, sliceIdx= None):
    tool.setCenterFrequency(deltaCF=0)
    print("Setting gradients only now")
    
    deltaLinGrad=tool.getSolutionsToApply(sliceIdx)[1:4]
    linGradSol= tool.getSolutions(sliceIdx)[1:4]

    label = ["x", "y", "z"]
    appliedGradientsResults = []
    expectedGradientResults = []
    differences = []
    for i in range(3):
        print(f"Setting {label[i]} gradient only now")
        lingrad = np.zeros(3)
        lingrad[i] = deltaLinGrad[i]
        if i == 1:
            lingrad[1] = - lingrad[1]
        tool.setLinGradients(deltaLinGrad=lingrad)
        tool.doFieldmapScan()
        appliedGradientsResults.append(computeFieldmapFromLatestFieldmapScan(tool))
        expectedGradientResults.append(tool.basisB0maps[i]*linGradSol[i] + background)
        print(f"Stats of the actual acquired fieldmap after only changing the {label[i]} linear gradients:\n", tool.shimStatStrsVolume[2])
        print(f"\n Comparing expected - applied results for gradient {label[i]}")
        differences.append(compare(expectedGradientResults[i], appliedGradientsResults[i]))
    return expectedGradientResults, appliedGradientsResults, differences

# %% [markdown]
# ### Volume wise

# %%
# for a slice on isocenter
# add a slider to select the slice
output_widget = widgets.Output()
startEvalScan = widgets.Button(description='Start Eval Scan')

def init_slice_eval(b):
    with output_widget:
        print("\n-------------")
        print(f"Evaluating results on Volume\n")
        expectedEach, appliedEach, differences = applyGradients1by1(tool, None)

sliceSlider.observe(on_slider_value_change, names='value')

startEvalScan.on_click(init_slice_eval)
# Layout the widgets
widgets_layout = widgets.VBox([startEvalScan, output_widget])
display(widgets_layout)

# %% [markdown]
# ## Determining why the y gradient is acting funky...

# %%
def plotPixelFieldStrengthsVsPosition(title, points, xlabel, ylabel, xlim, ylim):
    plt.scatter(points[:,0], points[:,1])
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.xlim(xlim)
    plt.ylim(ylim)

def getFieldStrengthPoints(fieldmap, c, pixelSize, fovCenter=[0,0,0], title=None):
    """
    for one dimensional direction:
        - collapse all strengths onto one dimension
        - compute the relative distance for each pixel position using pixelSize
        - create list of points (distanceFromIsocenter, fieldStrength)
        - plot the points
        - plot a line of best fit
    """
    points = [[],[],[]]
    # i want to take every non nan pixel value in the fieldmap
    # then for each pixel, get the distance from fovCenter, and the field strength and add to points list
    def get_distances(pos):
        shape = fieldmap.shape
        ret = []
        for i in range(3):
            ret.append((pos[i] - (shape[i]/2+.5)) * pixelSize[i] + fovCenter[i])
        return ret

    maxDist=0
    for y in range(fieldmap.shape[0]):
        for z in range(fieldmap.shape[1]):
            for x in range(fieldmap.shape[2]):
                if not np.isnan(fieldmap[y,z,x]):
                    fieldStrength = fieldmap[y,z,x]
                    distances = get_distances([y,z,x])
                    maxDist = max(maxDist, np.max(np.abs(distances)))
                    for i in range(3):
                        points[i].append([distances[i], fieldStrength])

    if title is not None:
        directions = ["Y", "Z", "X"]
        absheight=0
        for i in range(3):
            points[i] = np.array(points[i])
            absheight = max(absheight, np.nanmax(np.abs(points[i][:,1])))

        i = c
        plotPixelFieldStrengthsVsPosition(
            f"{title} Gradient Field Strength (Hz) vs Distance (mm) Isocenter in {directions[i]}", 
            points[i], 
            "Distance from Isocenter (mm)", 
            "Field Strength (Hz)", 
            [-maxDist, maxDist], 
            [-absheight, absheight]
            )
        plt.show()
    return [points[2], points[0], points[1]]

points = getFieldStrengthPoints(tool.basisB0maps[1], 0, [3,3,3], title="Y basis map")
points = getFieldStrengthPoints(tool.basisB0maps[0], 2, [3,3,3], title="X basis map")
points = getFieldStrengthPoints(tool.basisB0maps[2], 1, [3,3,3], title="Z basis map")

# %% [markdown]
# ## Need to evaluate how the y gradient basis map is being acquired

# %%
for i in range(20,100, 20):
    print(f"Applying y gradient at {i} ticks")
    tool.setCenterFrequency(0)
    tool.setLinGradients([0,i,0])
    tool.doFieldmapScan()
    basisRaw = computeFieldmapFromLatestFieldmapScan(tool)
    basis = basisRaw - background
    points = getFieldStrengthPoints(basis, 0, [3,3,3], title="Y basis map with gradient at {i}")

# %% [markdown]
# ### Stability test for ticks around 40-70

# %%
for i in range(50,71,10):
    for j in range(3):
        print(f"Applying y gradient at {i} ticks")
        tool.setCenterFrequency(0)
        tool.setLinGradients([0,i,0])
        tool.doFieldmapScan()
        basisRaw = computeFieldmapFromLatestFieldmapScan(tool)
        basis = basisRaw - background
        points = getFieldStrengthPoints(basis, 0, [3,3,3], title=f"Y basis map with gradient at {i}")

# %% [markdown]
# ### Slice wise

# %%
# for a slice on isocenter
# add a slider to select the slice
sliceSlider = widgets.IntSlider(description='Slice Idx:', disabled=False)
output_widget = widgets.Output()
startEvalScan = widgets.Button(description='Start Eval Scan')
sliceSlider.max = len(tool.shimStatsPerSlice[0]) - 1  # Update slider range
sliceSlider.value = 0  # Reset to first image
sliceIdx =  0 


# Update the displayed image when the slider value changes
def on_slider_value_change(change):
    if change['new'] is not None:
        sliceIdx = change['new']

        # visualize that slice
        with output_widget:
            clear_output(wait=True)
            plt.imshow(background_mag[:,sliceIdx], cmap='gray')
            plt.show()

            print("principle sols", tool.principleSols)
            print("solutions to apply for the volume", tool.getSolutionsToApply(sliceIdx))
            print("\nstats of the background:\n", tool.shimStatStrsPerSlice[0][sliceIdx])
            print("\nstats for expected:\n", tool.shimStatStrsPerSlice[1][sliceIdx])

def init_slice_eval(b):
    with output_widget:
        print("\n-------------")
        print(f"Evaluating results on Slice {sliceSlider.value}\n")
        beforeCFMoved, afterCFMoved = applyShimAndCompare(tool, sliceSlider.value)

        print("\n\nComparing background with before CF moved")
        diff = compare(background, beforeCFMoved)
        print("Comparing background with after CF moved")
        diff = compare(background, afterCFMoved)
        print("Comparing before CF moved with after CF moved")
        diff = compare(beforeCFMoved, afterCFMoved)
sliceSlider.observe(on_slider_value_change, names='value')

startEvalScan.on_click(init_slice_eval)
# Layout the widgets
widgets_layout = widgets.VBox([sliceSlider, startEvalScan, output_widget])
display(widgets_layout)

# %% [markdown]
# # Testing CF, Gradients, AND Shim Loop on solution one by one....

# %%
def applyShimAndCompare(tool: Tool, sliceIdx: int = None):
    tool.setCenterFrequency(deltaCF=0)

    print("Setting gradients only now")
    tool.setLinGradients(deltaLinGrad=tool.getSolutionsToApply(sliceIdx)[1:4])
    tool.doFieldmapScan()
    afterLinGrad = computeFieldmapFromLatestFieldmapScan(tool)
    print("Stats of the actual acquired fieldmap after only changing the linear gradients:\n", tool.shimStatStrsVolume[2])

    print("\nSetting shim loops now")
    for i in range(tool.shimInstance.numLoops):
        tool.sendSyncedLoopSolution(i, sliceIdx=sliceIdx)
    tool.doFieldmapScan()
    afterLinGradandShim = computeFieldmapFromLatestFieldmapScan(tool)
    print("Stats of the actual acquired fieldmap after adding shim loops:\n", tool.shimStatStrsVolume[2])


    print("\nSetting Center frequency now")
    tool.setCenterFrequency(deltaCF=tool.getSolutionsToApply(sliceIdx)[0])
    tool.doFieldmapScan()
    afterLinGradandShimandCF = computeFieldmapFromLatestFieldmapScan(tool)
    print("Stats of the actual acquired fieldmap after adding center frequency:\n", tool.shimStatStrsVolume[2])

    return afterLinGrad, afterLinGradandShim, afterLinGradandShimandCF

def compareToExpected(tool:Tool, afterLinGrad, afterLinGradandShim, afterLinGradandShimandCF):
    background = tool.backgroundB0Map.copy()
    print("Background Fieldmap Stats: ")
    printStats(background)

    for i in range(3):
        background += tool.basisB0maps[i] * tool.getSolutions(sliceIdx)[i+1]
    print(f"Expected: after changing linear gradients only")
    printStats(background)
    print(f"actual: after changing linear gradients only")
    printStats(afterLinGrad)
    print(f"Comparing Expected - Actual")
    diff = compare(background, afterLinGrad)

    for i in range(tool.shimInstance.numLoops):
        background += tool.basisB0maps[i+3] * tool.getSolutions(sliceIdx)[i+4]
    print(f"Expected: after changing linear gradients and applied shims")
    printStats(background)
    print(f"actual: after changing linear gradients and applied shims")
    printStats(afterLinGrad)
    print(f"Comparing Expected - Actual")
    diff = compare(background, afterLinGradandShim)

    background += np.ones(background.shape) * tool.getSolutions(sliceIdx)[0]
    print(f"Expected: after changing linear gradients and applied shims and adjusted center frequency")
    printStats(background)
    print(f"actual: after changing linear gradients and applied shims and adjusted center frequency")
    printStats(afterLinGrad)
    print(f"Comparing Expected - Actual")
    diff = compare(background, afterLinGradandShimandCF)
    return

# %%
# reset the shim tool object 
tool = load_tool()
# Out:
# /home/heartvista/Documents/robert/ge3t_shim_tool/logs/scannerLog.txt
# /home/heartvista/Documents/robert/ge3t_shim_tool/logs/arduinoLog.txt
# /home/heartvista/Documents/robert/ge3t_shim_tool/logs/guiLog.txt
# INFO SHIM CLIENT: Serial port opened successfully
# INFO EXSI CLIENT: Socket connected
# 13:31:09 SHIM TOOL: waiting for connection
# EXSI CLIENT DEBUG: Processing command:  ConnectToScanner product=newHV passwd=rTpAtD
# EXSI CLIENT DEBUG: Processing command:  NotifyEvent all=on
# Debug SHIM CLIENT: recieved msg: Ccalibrating a channel
# Debug SHIM CLIENT: recieved msg: calibrated a channel
# Debug SHIM CLIENT: recieved msg: calibrating a channel
# EXSI CLIENT DEBUG: Processing command:  GetExamInfo
# 13:31:09 SHIM TOOL: done waiting for connection
# 13:31:09 SHIM TOOL: Shim Tool is ready to use.
# Debug SHIM CLIENT: recieved msg: calibrated a channel
# Debug SHIM CLIENT: recieved msg: calibrating a channel
# Debug SHIM CLIENT: recieved msg: calibrated a channel
# Debug SHIM CLIENT: recieved msg: calibrating a channel
# Debug SHIM CLIENT: recieved msg: calibrated a channel
# Debug SHIM CLIENT: recieved msg: Done Calibrating
# INFO SHIM CLIENT: Connection Created successfully
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration4"
# EXSI CLIENT DEBUG: Task keys found in message:  [2]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=2
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16158<NotifyEvent recon=done, 128 images available. taskKey=2
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# Debug SHIM CLIENT: recieved msg: Z
# Debug SHIM CLIENT: recieved msg: Done Zeroing
# EXSI CLIENT DEBUG: Task keys found in message:  [3, 4]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=3
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan auto
# EXSI CLIENT DEBUG: Processing command:  GetPrescanValues
# EXSI CLIENT DEBUG: Center frequency found in message: 127697916
# EXSI CLIENT DEBUG: attempting to find the last used gradients
# EXSI CLIENT DEBUG: Debug: found that linear shims got set to [12, 10, 14]
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=4
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16174<NotifyEvent recon=done, 180 images available. taskKey=3
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16180<NotifyEvent recon=done, 180 images available. taskKey=4
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# Debug SHIM CLIENT: recieved msg: Z
# Debug SHIM CLIENT: recieved msg: Done Zeroing
# EXSI CLIENT DEBUG: Task keys found in message:  [5, 6]
# EXSI CLIENT DEBUG: Processing command:  SetShimValues x=42 y=10 z=14
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=5
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=6
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16194<NotifyEvent recon=done, 180 images available. taskKey=5
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# EXSI CLIENT DEBUG: Task keys found in message:  [7, 8]
# EXSI CLIENT DEBUG: Processing command:  SetShimValues x=12 y=40 z=14
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=7
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16204<NotifyEvent recon=done, 180 images available. taskKey=6
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=8
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16214<NotifyEvent recon=done, 180 images available. taskKey=7
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# EXSI CLIENT DEBUG: Task keys found in message:  [9, 10]
# EXSI CLIENT DEBUG: Processing command:  SetShimValues x=12 y=10 z=44
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=9
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16224<NotifyEvent recon=done, 180 images available. taskKey=8
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=10
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16234<NotifyEvent recon=done, 180 images available. taskKey=9
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  X 0 1.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 0 current 1.00
# EXSI CLIENT DEBUG: Processing command:  X 1 0.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 1 current 0.00
# EXSI CLIENT DEBUG: Processing command:  X 2 0.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 2 current 0.00
# EXSI CLIENT DEBUG: Processing command:  X 3 0.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 3 current 0.00
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 0; value: 1.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 1; value: 0.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 2; value: 0.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 3; value: 0.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# EXSI CLIENT DEBUG: Task keys found in message:  [11, 12]
# EXSI CLIENT DEBUG: Processing command:  SetShimValues x=12 y=10 z=14
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=11
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16244<NotifyEvent recon=done, 180 images available. taskKey=10
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=12
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16254<NotifyEvent recon=done, 180 images available. taskKey=11
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  X 1 1.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 1 current 1.00
# EXSI CLIENT DEBUG: Processing command:  X 0 0.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 0 current 0.00
# EXSI CLIENT DEBUG: Processing command:  X 2 0.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 2 current 0.00
# EXSI CLIENT DEBUG: Processing command:  X 3 0.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 3 current 0.00
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 1; value: 1.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 0; value: 0.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 2; value: 0.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 3; value: 0.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# EXSI CLIENT DEBUG: Task keys found in message:  [13, 14]
# EXSI CLIENT DEBUG: Processing command:  SetShimValues x=12 y=10 z=14
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=13
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16264<NotifyEvent recon=done, 180 images available. taskKey=12
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=14
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16274<NotifyEvent recon=done, 180 images available. taskKey=13
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  X 2 1.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 2 current 1.00
# EXSI CLIENT DEBUG: Processing command:  X 0 0.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 0 current 0.00
# EXSI CLIENT DEBUG: Processing command:  X 1 0.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 1 current 0.00
# EXSI CLIENT DEBUG: Processing command:  X 3 0.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 3 current 0.00
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 2; value: 1.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 0; value: 0.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 1; value: 0.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 3; value: 0.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# EXSI CLIENT DEBUG: Task keys found in message:  [15, 16]
# EXSI CLIENT DEBUG: Processing command:  SetShimValues x=12 y=10 z=14
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=15
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16284<NotifyEvent recon=done, 180 images available. taskKey=14
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=16
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16294<NotifyEvent recon=done, 180 images available. taskKey=15
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  X 3 1.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 3 current 1.00
# EXSI CLIENT DEBUG: Processing command:  X 0 0.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 0 current 0.00
# EXSI CLIENT DEBUG: Processing command:  X 1 0.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 1 current 0.00
# EXSI CLIENT DEBUG: Processing command:  X 2 0.0
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 2 current 0.00
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 3; value: 1.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 0; value: 0.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 1; value: 0.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 2; value: 0.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# EXSI CLIENT DEBUG: Task keys found in message:  [17, 18]
# EXSI CLIENT DEBUG: Processing command:  SetShimValues x=12 y=10 z=14
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=17
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16304<NotifyEvent recon=done, 180 images available. taskKey=16
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=18
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16314<NotifyEvent recon=done, 180 images available. taskKey=17
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16320<NotifyEvent recon=done, 180 images available. taskKey=18
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  Prescan values=hide cf=127697916
# EXSI CLIENT DEBUG: Processing command:  SetShimValues x=17 y=8 z=12
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# EXSI CLIENT DEBUG: Task keys found in message:  [19, 20]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=19
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=20
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16334<NotifyEvent recon=done, 180 images available. taskKey=19
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16340<NotifyEvent recon=done, 180 images available. taskKey=20
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  X 0 -0.09837283320649781
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 0 current -0.10
# EXSI CLIENT DEBUG: Processing command:  X 1 1.9985140264159915
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 1 current 2.00
# EXSI CLIENT DEBUG: Processing command:  X 2 -0.10744962901502515
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 2 current -0.11
# EXSI CLIENT DEBUG: Processing command:  X 3 -0.013317568620039324
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 3 current -0.01
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 0; value: -0.10
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 1; value: 2.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 2; value: -0.11
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 3; value: -0.01
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# EXSI CLIENT DEBUG: Task keys found in message:  [21, 22]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=21
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=22
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16354<NotifyEvent recon=done, 180 images available. taskKey=21
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16360<NotifyEvent recon=done, 180 images available. taskKey=22
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  Prescan values=hide cf=127697916
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# EXSI CLIENT DEBUG: Task keys found in message:  [23, 24]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=23
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=24
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16374<NotifyEvent recon=done, 180 images available. taskKey=23
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16380<NotifyEvent recon=done, 180 images available. taskKey=24
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  Prescan values=hide cf=127697916
# EXSI CLIENT DEBUG: Processing command:  SetShimValues x=12 y=10 z=14
# EXSI CLIENT DEBUG: Processing command:  X 0 -0.09837283320649781
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 0 current -0.10
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 0; value: -0.10
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# EXSI CLIENT DEBUG: Task keys found in message:  [25, 26]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=25
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=26
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16394<NotifyEvent recon=done, 180 images available. taskKey=25
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16400<NotifyEvent recon=done, 180 images available. taskKey=26
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  X 1 1.9985140264159915
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 1 current 2.00
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 1; value: 2.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# EXSI CLIENT DEBUG: Task keys found in message:  [27, 28]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=27
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=28
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16414<NotifyEvent recon=done, 180 images available. taskKey=27
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16420<NotifyEvent recon=done, 180 images available. taskKey=28
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  X 2 -0.10744962901502515
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 2 current -0.11
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 2; value: -0.11
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# EXSI CLIENT DEBUG: Task keys found in message:  [29, 30]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=29
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=30
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16434<NotifyEvent recon=done, 180 images available. taskKey=29
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16440<NotifyEvent recon=done, 180 images available. taskKey=30
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  X 3 -0.013317568620039324
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 3 current -0.01
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 3; value: -0.01
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# EXSI CLIENT DEBUG: Task keys found in message:  [31, 32]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=31
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=32
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16454<NotifyEvent recon=done, 180 images available. taskKey=31
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16460<NotifyEvent recon=done, 180 images available. taskKey=32
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  Prescan values=hide cf=127697916
# EXSI CLIENT DEBUG: Processing command:  SetShimValues x=17 y=8 z=12
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# EXSI CLIENT DEBUG: Task keys found in message:  [33, 34]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=33
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=34
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16474<NotifyEvent recon=done, 180 images available. taskKey=33
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16480<NotifyEvent recon=done, 180 images available. taskKey=34
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  X 0 -0.09837283320649781
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 0 current -0.10
# EXSI CLIENT DEBUG: Processing command:  X 1 1.9985140264159915
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 1 current 2.00
# EXSI CLIENT DEBUG: Processing command:  X 2 -0.10744962901502515
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 2 current -0.11
# EXSI CLIENT DEBUG: Processing command:  X 3 -0.013317568620039324
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 3 current -0.01
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 0; value: -0.10
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 1; value: 2.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 2; value: -0.11
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 3; value: -0.01
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# EXSI CLIENT DEBUG: Task keys found in message:  [35, 36]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=35
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=36
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16494<NotifyEvent recon=done, 180 images available. taskKey=35
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16500<NotifyEvent recon=done, 180 images available. taskKey=36
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  Prescan values=hide cf=127697916
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# EXSI CLIENT DEBUG: Task keys found in message:  [37, 38]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=37
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=38
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16514<NotifyEvent recon=done, 180 images available. taskKey=37
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16520<NotifyEvent recon=done, 180 images available. taskKey=38
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  Prescan values=hide cf=127697916
# EXSI CLIENT DEBUG: Processing command:  SetShimValues x=17 y=8 z=12
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# EXSI CLIENT DEBUG: Task keys found in message:  [39, 40]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=39
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=40
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16534<NotifyEvent recon=done, 180 images available. taskKey=39
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16540<NotifyEvent recon=done, 180 images available. taskKey=40
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  X 0 -0.09837283320649781
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 0 current -0.10
# EXSI CLIENT DEBUG: Processing command:  X 1 1.9985140264159915
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 1 current 2.00
# EXSI CLIENT DEBUG: Processing command:  X 2 -0.10744962901502515
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 2 current -0.11
# EXSI CLIENT DEBUG: Processing command:  X 3 -0.013317568620039324
# EXSI CLIENT Debug: SEND SYNC CURRENT COMMAND, channel 3 current -0.01
# EXSI CLIENT DEBUG: Processing command:  LoadProtocol site path="ConformalShimCalibration3"
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 0; value: -0.10
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 1; value: 2.00
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 2; value: -0.11
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# Debug SHIM CLIENT: recieved msg: X
# Debug SHIM CLIENT: recieved msg: board: 0; channel: 3; value: -0.01
# Debug SHIM CLIENT: recieved msg: Done Setting Current
# Debug SHIM CLIENT: recieved msg:
# EXSI CLIENT DEBUG: Task keys found in message:  [41, 42]
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=41
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=1104
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan
# EXSI CLIENT DEBUG: Processing command:  SelectTask taskkey=42
# EXSI CLIENT DEBUG: Processing command:  SetRxGeometry plane=coronal
# EXSI CLIENT DEBUG: Images are ready. in msg: <exsi-srv:27630:16554<NotifyEvent recon=done, 180 images available. taskKey=41
# EXSI CLIENT DEBUG: setting images_ready_event
# EXSI CLIENT DEBUG: Processing command:  SetGrxSlices center=0.0,0.0,-22 phaseNormal=10,0,0 freqNormal=0,0,10
# EXSI CLIENT DEBUG: Processing command:  ActivateTask
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_tr=6000
# EXSI CLIENT DEBUG: Processing command:  SetCVs act_te=4604
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhrcctrl=13
# EXSI CLIENT DEBUG: Processing command:  SetCVs rhimsize=64
# EXSI CLIENT DEBUG: Processing command:  PatientTable advanceToScan
# EXSI CLIENT DEBUG: Processing command:  Prescan skip
# EXSI CLIENT DEBUG: Processing command:  Scan

# %%
# acquire a new background
tool.doCalibrationScan()
tool.doFieldmapScan()
background = computeFieldmapFromLatestFieldmapScan(tool)

# for viewing purposes
tool.getROIBackgound()
background_mag = tool.viewData[0]
# Out:
# 13:31:44 SHIM TOOL: Initiating transfer using rsync.
# 13:31:44 SHIM TOOL: obtained exam data path: /export/home1/sdc_image_pool/images/p2/e2046
# 13:31:45 SHIM TOOL: resetting???
# 13:31:45 SHIM TOOL: Checking for failure on last run; On scan 1 / 2
# 13:31:45 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 1 / 2
# EXSI CLIENT DEBUG: found that the last bed position was -22 mm
# 13:32:29 SHIM TOOL: Checking for failure on last run; On scan 2 / 2
# 13:32:29 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 2 / 2
# 13:32:53 SHIM TOOL: Done. 2 scans completed!
# 13:32:53 SHIM TOOL: Initiating transfer using rsync.
# 13:32:53 SHIM TOOL: Initiating transfer using rsync.
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# 13:32:54 SHIM TOOL: Computed Mask from background, basis and ROI.
# 13:32:54 SHIM TOOL: Masked obtained data and 'sent to GUI.'
# 13:32:54 SHIM TOOL: evaluating map 0
# 13:32:54 SHIM TOOL: finished setting the per slice stats for map 0
# 13:32:54 SHIM TOOL: finished setting the volume stats for map 0
# 13:32:54 SHIM TOOL: evaluating map 1
# 13:32:54 SHIM TOOL: evaluating map 2
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# 13:32:55 SHIM TOOL: extracting the background mag image
# 13:32:55 SHIM TOOL: done extracting the background mag image

# %%
tool.doBasisCalibrationScans()
# Out:
# 13:33:04 SHIM TOOL: DEBUG: Setting linear gradients: principle lingrads [12. 10. 14.] + delta lingrads [30.  0.  0.] = [42. 10. 14.] to apply as rounded int
# 13:33:04 SHIM TOOL: Checking for failure on last run; On scan 1 / 14
# 13:33:04 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 1 / 14
# 13:33:06 SHIM TOOL: DEBUG: Setting linear gradients: principle lingrads [12. 10. 14.] + delta lingrads [ 0. 30.  0.] = [12. 40. 14.] to apply as rounded int
# 13:33:28 SHIM TOOL: Checking for failure on last run; On scan 2 / 14
# 13:33:28 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 2 / 14
# 13:33:52 SHIM TOOL: DEBUG: Setting linear gradients: principle lingrads [12. 10. 14.] + delta lingrads [ 0.  0. 30.] = [12. 10. 44.] to apply as rounded int
# 13:33:52 SHIM TOOL: Checking for failure on last run; On scan 3 / 14
# 13:33:52 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 3 / 14
# 13:34:15 SHIM TOOL: Checking for failure on last run; On scan 4 / 14
# 13:34:15 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 4 / 14
# 13:34:38 SHIM TOOL: Queueing shim loop calibrations 0 of 4
# 13:34:38 SHIM TOOL: Queueing loop 0 to 1.000: solToAply=1000.000, principle=0.000
# 13:34:38 SHIM TOOL: Queueing loop 1 zero
# 13:34:38 SHIM TOOL: Queueing loop 2 zero
# 13:34:38 SHIM TOOL: Queueing loop 3 zero
# 13:34:38 SHIM TOOL: DEBUG: Setting linear gradients: principle lingrads [12. 10. 14.] + delta lingrads [0. 0. 0.] = [12. 10. 14.] to apply as rounded int
# 13:34:39 SHIM TOOL: Checking for failure on last run; On scan 5 / 14
# 13:34:39 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 5 / 14
# 13:35:02 SHIM TOOL: Checking for failure on last run; On scan 6 / 14
# 13:35:02 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 6 / 14
# 13:35:25 SHIM TOOL: Queueing shim loop calibrations 1 of 4
# 13:35:25 SHIM TOOL: Queueing loop 1 to 1.000: solToAply=1000.000, principle=0.000
# 13:35:25 SHIM TOOL: Queueing loop 0 zero
# 13:35:25 SHIM TOOL: Queueing loop 2 zero
# 13:35:25 SHIM TOOL: Queueing loop 3 zero
# 13:35:25 SHIM TOOL: DEBUG: Setting linear gradients: principle lingrads [12. 10. 14.] + delta lingrads [0. 0. 0.] = [12. 10. 14.] to apply as rounded int
# 13:35:25 SHIM TOOL: Checking for failure on last run; On scan 7 / 14
# 13:35:25 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 7 / 14
# 13:35:48 SHIM TOOL: Checking for failure on last run; On scan 8 / 14
# 13:35:48 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 8 / 14
# 13:36:11 SHIM TOOL: Queueing shim loop calibrations 2 of 4
# 13:36:11 SHIM TOOL: Queueing loop 2 to 1.000: solToAply=1000.000, principle=0.000
# 13:36:11 SHIM TOOL: Queueing loop 0 zero
# 13:36:11 SHIM TOOL: Queueing loop 1 zero
# 13:36:11 SHIM TOOL: Queueing loop 3 zero
# 13:36:11 SHIM TOOL: DEBUG: Setting linear gradients: principle lingrads [12. 10. 14.] + delta lingrads [0. 0. 0.] = [12. 10. 14.] to apply as rounded int
# 13:36:12 SHIM TOOL: Checking for failure on last run; On scan 9 / 14
# 13:36:12 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 9 / 14
# 13:36:34 SHIM TOOL: Checking for failure on last run; On scan 10 / 14
# 13:36:34 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 10 / 14
# 13:36:58 SHIM TOOL: Queueing shim loop calibrations 3 of 4
# 13:36:58 SHIM TOOL: Queueing loop 3 to 1.000: solToAply=1000.000, principle=0.000
# 13:36:58 SHIM TOOL: Queueing loop 0 zero
# 13:36:58 SHIM TOOL: Queueing loop 1 zero
# 13:36:58 SHIM TOOL: Queueing loop 2 zero
# 13:36:58 SHIM TOOL: DEBUG: Setting linear gradients: principle lingrads [12. 10. 14.] + delta lingrads [0. 0. 0.] = [12. 10. 14.] to apply as rounded int
# 13:36:59 SHIM TOOL: Checking for failure on last run; On scan 11 / 14
# 13:36:59 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 11 / 14
# 13:37:21 SHIM TOOL: Checking for failure on last run; On scan 12 / 14
# 13:37:21 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 12 / 14
# 13:37:45 SHIM TOOL: Checking for failure on last run; On scan 13 / 14
# 13:37:45 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 13 / 14
# 13:38:08 SHIM TOOL: Checking for failure on last run; On scan 14 / 14
# 13:38:08 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 14 / 14
# 13:38:32 SHIM TOOL: Done. 14 scans completed!
# 13:38:32 SHIM TOOL: Initiating transfer using rsync.
# 13:38:35 SHIM TOOL: DEBUG: just finished all the calibration scans
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# 13:38:40 SHIM TOOL: Computed Mask from background, basis and ROI.
# 13:38:41 SHIM TOOL: Masked obtained data and 'sent to GUI.'
# 13:38:41 SHIM TOOL: Computed solutions and created new estimate shim maps
# 13:38:41 SHIM TOOL: evaluating map 0
# 13:38:41 SHIM TOOL: finished setting the per slice stats for map 0
# 13:38:41 SHIM TOOL: finished setting the volume stats for map 0
# 13:38:41 SHIM TOOL: evaluating map 1
# 13:38:41 SHIM TOOL: finished setting the per slice stats for map 1
# 13:38:41 SHIM TOOL: finished setting the volume stats for map 1
# 13:38:41 SHIM TOOL: evaluating map 2

# %%
tool.setShimMode(ShimMode.VOLUME)
tool.recomputeCurrentsAndView()
# Out:
# 13:38:50 SHIM TOOL: Computed Mask from background, basis and ROI.
# 13:38:50 SHIM TOOL: Masked obtained data and 'sent to GUI.'
# 13:38:50 SHIM TOOL: Computed Mask from background, basis and ROI.
# 13:38:51 SHIM TOOL: Masked obtained data and 'sent to GUI.'
# 13:38:51 SHIM TOOL: Computed solutions and created new estimate shim maps
# 13:38:51 SHIM TOOL: evaluating map 0
# 13:38:51 SHIM TOOL: finished setting the per slice stats for map 0
# 13:38:51 SHIM TOOL: finished setting the volume stats for map 0
# 13:38:51 SHIM TOOL: evaluating map 1
# 13:38:51 SHIM TOOL: finished setting the per slice stats for map 1
# 13:38:51 SHIM TOOL: finished setting the volume stats for map 1
# 13:38:51 SHIM TOOL: evaluating map 2

# %%
print("principle sols", tool.principleSols)
print("solutions to apply for the volume", tool.getSolutionsToApply())
print("\nstats of the background:\n", tool.shimStatStrsVolume[0])
print("\nstats for expected:\n", tool.shimStatStrsVolume[1])
# Out:
# principle sols [1.27697916e+08 1.20000000e+01 1.00000000e+01 1.40000000e+01
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00]
# solutions to apply for the volume [-4.43101707e+00  4.10170970e+00 -7.78727506e-01 -3.17232366e-01
#  -1.02177329e+02  5.55694620e+02 -6.83889228e+01 -1.90171262e+01]
#
# stats of the background:
#   RESULTS (Hz):
# St. Dev: 19.299
# Mean: -1.281
# Median: -0.770
# RMSE: 19.342
#
# stats for expected:
#   RESULTS (Hz):
# St. Dev: 16.185
# Mean: 0.000
# Median: 0.136
# RMSE: 16.185

# %%
# volume of the ROI
tool.setShimMode(ShimMode.VOLUME)

# somehow set an ROI that makes sense to you... it would be nice to be able to spawn the gui and select the ROI manually...that would be cool... 
# for now, lets just set a circle in the center of the image
ydim, zdim, xdim = tool.viewData[0].shape
tool.ROI.setROILimits(xdim, ydim, zdim)
tool.ROI.sizes[0] = max(1, round((tool.ROI.xdim // 2) * .65))
tool.ROI.sizes[1] = max(1, round((tool.ROI.ydim // 2) * .65))
tool.ROI.sizes[2] = max(1, round((tool.ROI.zdim // 2) * .65))
tool.ROI.centers[0] = round(tool.ROI.xdim * .45)
tool.ROI.centers[1] = round(tool.ROI.ydim * .6)
tool.ROI.centers[2] = round(tool.ROI.zdim * .5)
tool.ROI.enabled = True
tool.ROI.updated = True
tool.computeMask()
tool.recomputeCurrentsAndView()
tool.cropViewDataToFinalMask()
# Out:
# 13:42:14 SHIM TOOL: Computed Mask from background, basis and ROI.
# 13:42:14 SHIM TOOL: Computed Mask from background, basis and ROI.
# 13:42:14 SHIM TOOL: Masked obtained data and 'sent to GUI.'
# 13:42:15 SHIM TOOL: Computed Mask from background, basis and ROI.
# 13:42:15 SHIM TOOL: Masked obtained data and 'sent to GUI.'
# 13:42:15 SHIM TOOL: Computed solutions and created new estimate shim maps
# 13:42:15 SHIM TOOL: evaluating map 0
# 13:42:15 SHIM TOOL: finished setting the per slice stats for map 0
# 13:42:15 SHIM TOOL: finished setting the volume stats for map 0
# 13:42:15 SHIM TOOL: evaluating map 1
# 13:42:15 SHIM TOOL: finished setting the per slice stats for map 1
# 13:42:15 SHIM TOOL: finished setting the volume stats for map 1
# 13:42:15 SHIM TOOL: evaluating map 2
# 13:42:15 SHIM TOOL: Masked obtained data and 'sent to GUI.'

# %%
background_cropped = np.copy(background_mag).astype(np.float32)
background_cropped[~tool.finalMask] = np.nan

# %%
# for a slice on isocenter
# add a slider to select the slice
sliceSlider = widgets.IntSlider(description='Slice Idx:', disabled=False)
output_widget = widgets.Output()
sliceSlider.max = len(tool.shimStatsPerSlice[0]) - 1  # Update slider range
sliceSlider.value = 0  # Reset to first image
sliceIdx =  0 


# Update the displayed image when the slider value changes
def on_slider_value_change(change):
    if change['new'] is not None:
        sliceIdx = change['new']

        # visualize that slice
        with output_widget:
            clear_output(wait=True)
            plt.imshow(background_cropped[:,sliceIdx], cmap='gray')
            plt.show()

            print("principle sols", tool.principleSols)
            print("solutions to apply for the volume", tool.getSolutionsToApply(sliceIdx))
            print("\nstats of the background:\n", tool.getSolutionStrings(0))
            print("\nstats for expected:\n", tool.getSolutionStrings(1))

sliceSlider.observe(on_slider_value_change, names='value')

# Layout the widgets
widgets_layout = widgets.VBox([sliceSlider, output_widget])
display(widgets_layout)
# Out:
# VBox(children=(IntSlider(value=0, description='Slice Idx:', max=63), Output()))

# %%
# for a slice on isocenter
# add a slider to select the slice
startEvalScan = widgets.Button(description='Start Eval Scan')
output_widget = widgets.Output()

def init_slice_eval(b):
    with output_widget:
        print("\n-------------")
        print(f"Evaluating results on ROI")
        scans = applyShimAndCompare(tool, None)
        compareToExpected(tool, *scans)

startEvalScan.on_click(init_slice_eval)
# Layout the widgets
widgets_layout = widgets.VBox([startEvalScan, output_widget])
display(widgets_layout)
# Out:
# VBox(children=(Button(description='Start Eval Scan', style=ButtonStyle()), Output()))

# %% [markdown]
# ## Trying to understand which shim loop is bad or if they are all just bad

# %%
def applyShimLoops1by1(tool: Tool, sliceIdx= None):
    tool.setCenterFrequency(deltaCF=0)
    tool.setLinGradients([0,0,0])
    print("Setting shimloops only now")
    
    expectedShimResults = []
    appliedShimResults = []
    differences = []
    for i in range(tool.shimInstance.numLoops):
        print(f"\n\n-----------------\napplying shim loop {i}")
        tool.sendSyncedLoopSolution(i, sliceIdx=sliceIdx)
        tool.doFieldmapScan()
        appliedShimResults.append(computeFieldmapFromLatestFieldmapScan(tool))
        expectedShimResults.append(tool.basisB0maps[i]*tool.getSolutions(sliceIdx)[i] + background)
        print(f"Stats of the actual acquired fieldmap after only changing shim loop {i}:\n", tool.shimStatStrsVolume[2])
        print(f"\n Comparing expected - applied results for shim loop {i}")
        differences.append(compare(expectedShimResults[i], appliedShimResults[i]))
    return expectedShimResults, appliedShimResults, differences

# %%
applyShimLoops1by1(tool, None)
# Out:
# 13:51:56 SHIM TOOL: DEBUG: Setting center frequency: principle cf 127697916.0 + delta CF 0 = 127697916 to apply as int
# 13:51:56 SHIM TOOL: DEBUG: Setting linear gradients: principle lingrads [12. 10. 14.] + delta lingrads [0. 0. 0.] = [12. 10. 14.] to apply as rounded int
# Setting shimloops only now
#
#
# -----------------
# applying shim loop 0
# 13:51:56 SHIM TOOL: Queueing loop 0 to -0.098: solToAply=-98.373, principle=0.000
# 13:51:56 SHIM TOOL: Checking for failure on last run; On scan 1 / 2
# 13:51:56 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 1 / 2
# 13:52:20 SHIM TOOL: Checking for failure on last run; On scan 2 / 2
# 13:52:20 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 2 / 2
# 13:52:44 SHIM TOOL: Done. 2 scans completed!
# 13:52:44 SHIM TOOL: Initiating transfer using rsync.
# 13:52:45 SHIM TOOL: Initiating transfer using rsync.
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# 13:52:46 SHIM TOOL: saved volume shimmed b0map
# 13:52:46 SHIM TOOL: Masked obtained data and 'sent to GUI.'
# 13:52:46 SHIM TOOL: evaluating map 0
# 13:52:46 SHIM TOOL: finished setting the per slice stats for map 0
# 13:52:46 SHIM TOOL: finished setting the volume stats for map 0
# 13:52:46 SHIM TOOL: evaluating map 1
# 13:52:46 SHIM TOOL: finished setting the per slice stats for map 1
# 13:52:46 SHIM TOOL: finished setting the volume stats for map 1
# 13:52:46 SHIM TOOL: evaluating map 2
# 13:52:46 SHIM TOOL: finished setting the per slice stats for map 2
# 13:52:46 SHIM TOOL: finished setting the volume stats for map 2
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# Stats of the actual acquired fieldmap after only changing shim loop 0:
#   RESULTS (Hz):
# St. Dev: 10.872
# Mean: -0.784
# Median: -0.952
# RMSE: 10.900
#
#  Comparing expected - applied results for shim loop 0
# Difference Statistics:
# Mean:  3.359090007005523
# Std Dev:  20.05317716363482
#
#
# -----------------
# applying shim loop 1
# 13:52:47 SHIM TOOL: Queueing loop 1 to 1.999: solToAply=1998.514, principle=0.000
# 13:52:47 SHIM TOOL: Checking for failure on last run; On scan 1 / 2
# 13:52:47 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 1 / 2
# 13:53:12 SHIM TOOL: Checking for failure on last run; On scan 2 / 2
# 13:53:12 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 2 / 2
# 13:53:36 SHIM TOOL: Done. 2 scans completed!
# 13:53:36 SHIM TOOL: Initiating transfer using rsync.
# 13:53:37 SHIM TOOL: Initiating transfer using rsync.
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# 13:53:38 SHIM TOOL: saved volume shimmed b0map
# 13:53:38 SHIM TOOL: Masked obtained data and 'sent to GUI.'
# 13:53:38 SHIM TOOL: evaluating map 0
# 13:53:38 SHIM TOOL: finished setting the per slice stats for map 0
# 13:53:38 SHIM TOOL: finished setting the volume stats for map 0
# 13:53:38 SHIM TOOL: evaluating map 1
# 13:53:38 SHIM TOOL: finished setting the per slice stats for map 1
# 13:53:38 SHIM TOOL: finished setting the volume stats for map 1
# 13:53:38 SHIM TOOL: evaluating map 2
# 13:53:38 SHIM TOOL: finished setting the per slice stats for map 2
# 13:53:38 SHIM TOOL: finished setting the volume stats for map 2
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# Stats of the actual acquired fieldmap after only changing shim loop 1:
#   RESULTS (Hz):
# St. Dev: 12.429
# Mean: -1.817
# Median: -2.418
# RMSE: 12.561
#
#  Comparing expected - applied results for shim loop 1
# Difference Statistics:
# Mean:  -3.0537086782483747
# Std Dev:  10.518476132155458
#
#
# -----------------
# applying shim loop 2
# 13:53:39 SHIM TOOL: Queueing loop 2 to -0.107: solToAply=-107.450, principle=0.000
# 13:53:39 SHIM TOOL: Checking for failure on last run; On scan 1 / 2
# 13:53:39 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 1 / 2
# 13:54:03 SHIM TOOL: Checking for failure on last run; On scan 2 / 2
# 13:54:03 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 2 / 2
# 13:54:27 SHIM TOOL: Done. 2 scans completed!
# 13:54:27 SHIM TOOL: Initiating transfer using rsync.
# 13:54:28 SHIM TOOL: Initiating transfer using rsync.
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# 13:54:29 SHIM TOOL: saved volume shimmed b0map
# 13:54:29 SHIM TOOL: Masked obtained data and 'sent to GUI.'
# 13:54:29 SHIM TOOL: evaluating map 0
# 13:54:29 SHIM TOOL: finished setting the per slice stats for map 0
# 13:54:29 SHIM TOOL: finished setting the volume stats for map 0
# 13:54:29 SHIM TOOL: evaluating map 1
# 13:54:29 SHIM TOOL: finished setting the per slice stats for map 1
# 13:54:29 SHIM TOOL: finished setting the volume stats for map 1
# 13:54:29 SHIM TOOL: evaluating map 2
# 13:54:29 SHIM TOOL: finished setting the per slice stats for map 2
# 13:54:29 SHIM TOOL: finished setting the volume stats for map 2
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# Stats of the actual acquired fieldmap after only changing shim loop 2:
#   RESULTS (Hz):
# St. Dev: 11.086
# Mean: -1.006
# Median: -0.477
# RMSE: 11.131
#
#  Comparing expected - applied results for shim loop 2
# Difference Statistics:
# Mean:  1.9151741043638217
# Std Dev:  6.350827200260411
#
#
# -----------------
# applying shim loop 3
# 13:54:30 SHIM TOOL: Queueing loop 3 to -0.013: solToAply=-13.318, principle=0.000
# 13:54:30 SHIM TOOL: Checking for failure on last run; On scan 1 / 2
# 13:54:30 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 1 / 2
# 13:54:55 SHIM TOOL: Checking for failure on last run; On scan 2 / 2
# 13:54:55 SHIM TOOL: No Fail. Waiting for scan to complete, On scan 2 / 2
# 13:55:19 SHIM TOOL: Done. 2 scans completed!
# 13:55:19 SHIM TOOL: Initiating transfer using rsync.
# 13:55:20 SHIM TOOL: Initiating transfer using rsync.
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# 13:55:21 SHIM TOOL: saved volume shimmed b0map
# 13:55:21 SHIM TOOL: Masked obtained data and 'sent to GUI.'
# 13:55:21 SHIM TOOL: evaluating map 0
# 13:55:21 SHIM TOOL: finished setting the per slice stats for map 0
# 13:55:21 SHIM TOOL: finished setting the volume stats for map 0
# 13:55:21 SHIM TOOL: evaluating map 1
# 13:55:21 SHIM TOOL: finished setting the per slice stats for map 1
# 13:55:21 SHIM TOOL: finished setting the volume stats for map 1
# 13:55:21 SHIM TOOL: evaluating map 2
# 13:55:21 SHIM TOOL: finished setting the per slice stats for map 2
# 13:55:21 SHIM TOOL: finished setting the volume stats for map 2
# DEBUG: Extracted te1 1.104, name1 st
# DEBUG: Extracted te2 4.604, name2 nd
# Stats of the actual acquired fieldmap after only changing shim loop 3:
#   RESULTS (Hz):
# St. Dev: 10.187
# Mean: -1.519
# Median: -1.011
# RMSE: 10.300
#
#  Comparing expected - applied results for shim loop 3
# Difference Statistics:
# Mean:  -3.3094085222325926
# Std Dev:  6.350970303940985
# ([array([[[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]]]),
#   array([[[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]]]),
#   array([[[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]]]),
#   array([[[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]]])],
#  [array([[[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]]]),
#   array([[[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]]]),
#   array([[[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]]]),
#   array([[[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]]])],
#  [array([[[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]]]),
#   array([[[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]]]),
#   array([[[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]]]),
#   array([[[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          ...,
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]],
#
#          [[nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           ...,
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan],
#           [nan, nan, nan, ..., nan, nan, nan]]])])
